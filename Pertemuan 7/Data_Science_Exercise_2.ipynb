# %%
data={
    'Participant':['Joko','Lina','Mario','Andy','Simon'],
    'Age':['19','16','17','22','19'],
    'Talent':['Magic','Sing','Acrobat','Dance','Comedy'],
    'Origin':['Indonesia','China','Bulgaria','USA','France']
      }

# %%
df = pd.DataFrame(data)

# %%
df.to_csv('output_data.csv', index=False)

# %%
print("DataFrame successfully written to 'output_data.csv'.")
print(df)
# Out:
# DataFrame successfully written to 'output_data.csv'.
#   Participant Age   Talent     Origin
# 0        Joko  19    Magic  Indonesia
# 1        Lina  16     Sing      China
# 2       Mario  17  Acrobat   Bulgaria
# 3        Andy  22    Dance        USA
# 4       Simon  19   Comedy     France
