# %%
import pandas as pd
df = pd.read_csv('negarakecil.csv', index_col=0)
print(df)
# Out:
#                            Capital    Area   Population
# Country
# San Marino     Citta di San Marino      61       34,200
# Liechtenstein                Vaduz     160       40,500
# Maldives                      Male     298      531,000
# Malta                     Valletta     316      570,000
# Andorra           Andorra la Vella     468       89,000
# Singapore                Singapore     726    6,111,200
# Bahrain                     Manama     778    1,588,670
# Luxembourg         Luxembourg City   2,586      135,000
# Cape Verde                   Praia   4,033      491,233
# Cyprus                     Nicosia   9,251    1,295,102

# %%
data = {
    'Country':['San Marino','Liechtenstein','Maldives','Malta','Andorra','Singapore','Bahrain','Luxembourg','Cape Verde','Cyprus'],
    'Capital':['Citta di San Marino','Vaduz', 'Male','Valletta','Andorra la Vella','Singapore','Manama','Luxembourg City','Praia','Nicosia'],
    'Area':[61,160,298,316,468,726,778,2586,4033,9251],
    'Population':[34200,40500,531000,570000,89000,6111200,1588670,135000,491233,1295102]
}
df = pd.DataFrame(data)
mean = df.Population.mean()
std = df.Area.std()

# %%
print(df)
print(mean)
print(std)
# Out:
#          Country              Capital  Area  Population
# 0     San Marino  Citta di San Marino    61       34200
# 1  Liechtenstein                Vaduz   160       40500
# 2       Maldives                 Male   298      531000
# 3          Malta             Valletta   316      570000
# 4        Andorra     Andorra la Vella   468       89000
# 5      Singapore            Singapore   726     6111200
# 6        Bahrain               Manama   778     1588670
# 7     Luxembourg      Luxembourg City  2586      135000
# 8     Cape Verde                Praia  4033      491233
# 9         Cyprus              Nicosia  9251     1295102
# 1088590.5
# 2890.978652060002
