# %%
def write_biodata(filename):
    name = input("Enter your Name: ")
    age = input("Enter your Age: ")
    address = input("Enter your Address: ")
    email = input("Enter your Email: ")
    with open(filename, "w") as file:
        file.write(f"Name: {name}\n")
        file.write(f"Age: {age}\n")
        file.write(f"Address: {address}\n")
        file.write(f"Email: {email}\n")
    print(f"Successfully saved to {filename}.")

def read_biodata(filename):
    print(f"\n--- Reading {filename} ---")
    with open(filename, "r") as file:
         content = file.read()
    print(content)

file_name = "Biodata.txt"
write_biodata(file_name)
read_biodata(file_name)
# Out:
# Enter your Name: lukman
# Enter your Age: 40
# Enter your Address: bintaro
# Enter your Email: lukman@yahoo.com
# Successfully saved to Biodata.txt.
#
# --- Reading Biodata.txt ---
# Name: lukman
# Age: 40
# Address: bintaro
# Email: lukman@yahoo.com
